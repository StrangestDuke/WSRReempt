# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot([0,1,2,3],[0,2,4,7], label='2x', color='red')

plt.title("Bebpsis")

x2=np.arange(0,4.5,0.5)
#По сути это вынесение графвика по координатам, а потом ещё и построение дополнительного графика
#По тем-же координатам, только первый граф строится до 5 точки, а второй с 4
plt.plot(x2[:5], x2[:5]**2,'blue', label='X^2')
plt.plot(x2[4:],x2[4:]**2,'b--')
plt.xlabel("Bupsis")
plt.ylabel("Bipsus")

plt.legend()

plt.show()

# %%
plt.bar(["Bitches","Dick","balls","jeez"],[0,1,2,3])
# Out:
# <BarContainer object of 4 artists>

# %%
df_gas = pd.read_csv("../db/gas_prices.csv")

# %%
df_gas = df_gas[~df_gas.isnull().any(axis=1)]

# %%
df_gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         19 non-null     int64
#  1   Australia    18 non-null     float64
#  2   Canada       19 non-null     float64
#  3   France       19 non-null     float64
#  4   Germany      19 non-null     float64
#  5   Italy        19 non-null     float64
#  6   Japan        19 non-null     float64
#  7   Mexico       19 non-null     float64
#  8   South Korea  19 non-null     float64
#  9   UK           19 non-null     float64
#  10  USA          19 non-null     float64
# dtypes: float64(10), int64(1)
# memory usage: 1.8 KB

# %%
columns = df_gas.columns[1:]
plt.plot(df_gas.Year, df_gas.USA,'b.-',label='USA')
plt.plot(df_gas.Year, df_gas.Canada, 'y.-',label='Canada')
plt.plot(df_gas.Year, df_gas['South Korea'],'g.-', label='Korea')
plt.title('Gas Prices in USD')

plt.xticks(df_gas.Year[::3])

plt.xlabel('Year')
plt.ylabel('USD')

plt.legend()

plt.show()

# %%
df_fifa = pd.read_csv("../db/fifa_data.csv")

# %%
df_fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
bins = [40,50,60,70,80,90,100]
plt.hist(df_fifa.Overall,bins=bins)
plt.ylabel('number of players')
plt.xlabel('skill level')
plt.title('the ammount of sucked dicks distibution in mmo players, compared to hours played')
# Out:
# Text(0.5, 1.0, 'the ammount of sucked dicks distibution in mmo players, compared to hours played')

# %%
left = df_fifa[df_fifa['Preferred Foot'] == "Left"].count()[0]
right = df_fifa[df_fifa['Preferred Foot'] == "Right"].count()[0]

labels = ["Left","Right"]

plt.pie([left,right],labels=labels, autopct='%.2f %%')

plt.title('Preffered ass cheek to being slapped')

plt.show()
# Out:
# C:\Users\Strange\AppData\Local\Temp\ipykernel_10748\2725495212.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   left = df_fifa[df_fifa['Preferred Foot'] == "Left"].count()[0]
# C:\Users\Strange\AppData\Local\Temp\ipykernel_10748\2725495212.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   right = df_fifa[df_fifa['Preferred Foot'] == "Right"].count()[0]

# %%
df_fifa['Weight'] = (df_fifa['Weight'].str.strip().str[:3].astype(float) / 2.205)

# %%
df_fifa

# %%
light= df_fifa[df_fifa['Weight']< 125/2.205].count()[0]
light_medium= df_fifa[(df_fifa['Weight']>= 125/2.205) & (df_fifa['Weight'] < 150/2.205)].count()[0]
medium= df_fifa[(df_fifa['Weight'] >= 150/2.205) & (df_fifa['Weight'] < 175/2.205)].count()[0]
medium_heavy= df_fifa[(df_fifa['Weight'] >= 175) & (df_fifa['Weight'] < 200/2.205)].count()[0]
heavy= df_fifa[(df_fifa['Weight'] >= 200/2.205)].count()[0]
# Out:
# C:\Users\Strange\AppData\Local\Temp\ipykernel_10748\721282518.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light= df_fifa[df_fifa['Weight']< 125/2.205].count()[0]
# C:\Users\Strange\AppData\Local\Temp\ipykernel_10748\721282518.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light_medium= df_fifa[(df_fifa['Weight']>= 125/2.205) & (df_fifa['Weight'] < 150/2.205)].count()[0]
# ...

# %%
explode=(0.3,0.1,0.3,0,0)

# %%
weights = [light, light_medium, medium, medium_heavy, heavy]

# %%
labels = ['Undex 125','125-150','150-175','175-200','200 n` cock',]
plt.pie(weights,labels = labels, autopct='%.2f %%', pctdistance=0.8, explode=explode)
plt.show()

# %%
clubs = df_fifa['Club'].unique()

clubs_with_members = list()

for i in clubs:
    club_members = df_fifa[df_fifa['Club'] == i]['Overall'].copy()
    clubs_with_members.append(club_members)

# %%
a = len(clubs_with_members)

# %%
import math

# %%
plt.boxplot(clubs_with_members[40:50])
plt.show()

# %%
stuff = np.arange(1,math.ceil(a/10))
prev_num = 0
for i in stuff:
    cur_num = i*10
    prev_num = cur_num-10
    plt.boxplot(clubs_with_members[prev_num:cur_num])
    plt.show()

# %%
print(clubs_with_members[10:20])
# Out:
# [26       88
# 58       86
# 59       86
# 61       86
# 81       85
# 118      84
# 161      83
# 241      82
# 296      82
# 302      82
# 368      81
# 370      81
# 409      81
# 481      80
# 483      80
# 515      80
# 529      80
# 665      79
# 703      79
# 735      78
# 755      78
# 1063     77
# 1194     77
# 2405     74
# 4763     70
# 8853     66
# 13503    62
# 13961    61
# 14036    61
# 14252    61
# 14674    60
# 15378    59
# 15627    59
# Name: Overall, dtype: int64, 29      88
# 44      87
# 50      87
# 52      87
# 137     84
# 150     84
# 190     83
# 326     81
# 339     81
# 340     81
# 350     81
# 358     81
# 367     81
# 615     79
# 690     79
# 702     79
# 781     78
# 817     78
# 1156    77
# 1254    76
# 1616    75
# 1763    75
# 1859    75
# 2769    73
# 5179    70
# Name: Overall, dtype: int64, 33       88
# 74       86
# 87       85
# 131      84
# 146      84
# 199      83
# 235      82
# 281      82
# 289      82
# 311      82
# 317      82
# ...
